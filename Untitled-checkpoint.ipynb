# %%
import easyocr
import numpy as np

# %%
import cv2
from matplotlib import pyplot as plt
import imutils

# %%
img =cv2.imread("image2.jpg")

# %%
img
# Out:
# array([[[163, 159, 135],
#         [164, 160, 136],
#         [164, 160, 136],
#         ...,
#         [165, 151, 122],
#         [165, 151, 122],
#         [165, 151, 123]],
#
#        [[152, 148, 124],
#         [153, 149, 125],
#         [154, 150, 126],
#         ...,
#         [164, 150, 121],
#         [164, 150, 121],
#         [165, 151, 123]],
#
#        [[149, 145, 121],
#         [150, 146, 122],
#         [151, 147, 123],
#         ...,
#         [165, 154, 124],
#         [166, 155, 125],
#         [167, 155, 127]],
#
#        ...,
#
#        [[159, 160, 144],
#         [164, 165, 149],
#         [113, 115,  96],
#         ...,
#         [ 95,  93,  82],
#         [101,  99,  88],
#         [107, 105,  94]],
#
#        [[132, 133, 117],
#         [123, 124, 108],
#         [107, 109,  90],
#         ...,
#         [ 80,  78,  67],
#         [ 82,  80,  69],
#         [ 85,  83,  72]],
#
#        [[123, 124, 108],
#         [ 97,  98,  82],
#         [115, 117,  98],
#         ...,
#         [ 89,  87,  76],
#         [ 87,  85,  74],
#         [ 85,  83,  72]]], dtype=uint8)

# %%
plt.imshow(img)

# %%
mask = np.zeros(np.uint8)
new_image = cv2.drawContours(mask, [location], 0,255, -1)
new_image = cv2.bitwise_and(img, img, mask=mask)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10776/3360423837.py in <module>
# ----> 1 mask = np.zeros(gray.shape, np.uint8)
#       2 new_image = cv2.drawContours(mask, [location], 0,255, -1)
#       3 new_image = cv2.bitwise_and(img, img, mask=mask)
#
# NameError: name 'gray' is not defined
